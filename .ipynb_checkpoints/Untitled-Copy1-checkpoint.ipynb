# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\gq_wh\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\gq_wh\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
from citipy import citipy
import pandas as pd

# %%
import numpy as np

# %%
lats=np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs=np.random.uniform(low=-180.000, high=180.000, size=1500)

# %%
lat_lngs=list(zip(lats,lngs))

# %%
import time

# %%
cities=[]
countries=[]
for lat_lng in lat_lngs:
    city=citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    country=citipy.nearest_city(lat_lng[0],lat_lng[1]).country_code
    if city not in cities:
        cities.append(city)
        countries.append(country)

# %%
len(cities)
# Out:
# 594

# %%
len(countries)
# Out:
# 594

# %%
cities_countries=list(zip(cities,countries))

# %%
from api_keys import api_key
import requests

# %%
df=pd.DataFrame(cities_countries)
df.columns=['City','Country']
df['Lat']=''
df['Lng']=''
df['Date']=''
df['Temp']=''
df['Cloudiness']=''
df['Humidity']=''
df['Wind speed']=''
df=df.set_index('City')

# %%
base_url='http://api.openweathermap.org/data/2.5/weather?'
appid=api_key
response=[]
i=1
print ('Begining processing\n')
for city_country in cities_countries:
    url=f'{base_url}appid={appid}&q={city_country[0]},{city_country[1]}'
    r=requests.get(url).json()
    if r['cod']=='404':
        print ('City Not Found, skipping')
    else:
        print (f'processing request {i}: city name --- {city_country[0].capitalize()},{city_country[1].upper()}')    
        df.loc[city_country[0],'Lat']=r['coord']['lat']
        df.loc[city_country[0],'Lng']=r['coord']['lon']
        df.loc[city_country[0],'Date']=r['dt']
        df.loc[city_country[0],'Temp']=r['main']['temp']
        df.loc[city_country[0],'Cloudiness']=r['clouds']['all']
        df.loc[city_country[0],'Humidity']=r['main']['humidity']
        df.loc[city_country[0],'Wind speed']=r['wind']['speed']  
    time.sleep(1)
    i+=1
# Out:
# Begining processing
#
# City Not Found, skipping
# processing request 2: city name --- Rocha,UY
# processing request 3: city name --- Hermanus,ZA
# processing request 4: city name --- Fortuna,US
# processing request 5: city name --- Busselton,AU
# processing request 6: city name --- Killybegs,IE
# processing request 7: city name --- Bluff,NZ
# processing request 8: city name --- Punta arenas,CL
# processing request 9: city name --- Beloha,MG
# processing request 10: city name --- Bambous virieux,MU
# processing request 11: city name --- East london,ZA
# processing request 12: city name --- Vao,NC
# processing request 13: city name --- Esperance,AU
# processing request 14: city name --- Zaysan,KZ
# processing request 15: city name --- Ushuaia,AR
# processing request 16: city name --- Quepos,CR
# processing request 17: city name --- Saskylakh,RU
# City Not Found, skipping
# processing request 19: city name --- Kosh-agach,RU
# City Not Found, skipping
# processing request 21: city name --- Veraval,IN
# processing request 22: city name --- Aklavik,CA
# processing request 23: city name --- Sao filipe,CV
# processing request 24: city name --- Imbituba,BR
# processing request 25: city name --- Khatanga,RU
# processing request 26: city name --- Bruiu,RO
# processing request 27: city name --- Naze,JP
# processing request 28: city name --- Rikitea,PF
# processing request 29: city name --- New norfolk,AU
# processing request 30: city name --- Upington,ZA
# processing request 31: city name --- Albany,AU
# processing request 32: city name --- Puerto ayora,EC
# processing request 33: city name --- Hilo,US
# processing request 34: city name --- Alofi,NU
# processing request 35: city name --- Norman wells,CA
# processing request 36: city name --- Kirakira,SB
# processing request 37: city name --- Bredasdorp,ZA
# processing request 38: city name --- Severo-kurilsk,RU
# processing request 39: city name --- Alirajpur,IN
# processing request 40: city name --- Huarmey,PE
# processing request 41: city name --- Usinsk,RU
# processing request 42: city name --- Jamestown,SH
# processing request 43: city name --- Saint-philippe,RE
# processing request 44: city name --- Seoul,KR
# processing request 45: city name --- Souillac,MU
# processing request 46: city name --- Sola,VU
# processing request 47: city name --- Itarema,BR
# processing request 48: city name --- Pevek,RU
# processing request 49: city name --- Todos santos,MX
# processing request 50: city name --- Boa vista,BR
# processing request 51: city name --- Rio bueno,CL
# processing request 52: city name --- Cape town,ZA
# City Not Found, skipping
# processing request 54: city name --- College,US
# processing request 55: city name --- Alice springs,AU
# processing request 56: city name --- Khiv,RU
# processing request 57: city name --- Ribeira grande,PT
# processing request 58: city name --- Vestmannaeyjar,IS
# processing request 59: city name --- Kodiak,US
# processing request 60: city name --- Atuona,PF
# processing request 61: city name --- Lubana,LV
# processing request 62: city name --- Ushtobe,KZ
# processing request 63: city name --- Ecatepec,MX
# processing request 64: city name --- Fort-shevchenko,KZ
# processing request 65: city name --- Hithadhoo,MV
# processing request 66: city name --- Georgetown,SH
# processing request 67: city name --- Kulhudhuffushi,MV
# City Not Found, skipping
# processing request 69: city name --- Castro,CL
# City Not Found, skipping
# processing request 71: city name --- Kavieng,PG
# processing request 72: city name --- Coari,BR
# processing request 73: city name --- Ponta do sol,CV
# processing request 74: city name --- Xinxiang,CN
# processing request 75: city name --- Marsa matruh,EG
# processing request 76: city name --- Tasiilaq,GL
# processing request 77: city name --- Shelburne,CA
# processing request 78: city name --- Yellowknife,CA
# City Not Found, skipping
# processing request 80: city name --- Manokwari,ID
# processing request 81: city name --- Nikolskoye,RU
# City Not Found, skipping
# processing request 83: city name --- Faanui,PF
# processing request 84: city name --- Dikson,RU
# City Not Found, skipping
# processing request 86: city name --- Nampula,MZ
# City Not Found, skipping
# processing request 88: city name --- Grindavik,IS
# processing request 89: city name --- Hobart,AU
# processing request 90: city name --- Kiyasovo,RU
# processing request 91: city name --- Isangel,VU
# City Not Found, skipping
# processing request 93: city name --- Port macquarie,AU
# processing request 94: city name --- Kisangani,CD
# processing request 95: city name --- Qaanaaq,GL
# City Not Found, skipping
# processing request 97: city name --- Dewa,IN
# processing request 98: city name --- Chokurdakh,RU
# processing request 99: city name --- Surgut,RU
# processing request 100: city name --- Erdenet,MN
# processing request 101: city name --- Kapaa,US
# processing request 102: city name --- Butaritari,KI
# processing request 103: city name --- Yulara,AU
# City Not Found, skipping
# processing request 105: city name --- Saint-francois,GP
# processing request 106: city name --- Port alfred,ZA
# processing request 107: city name --- Nannilam,IN
# processing request 108: city name --- Petropavlovsk-kamchatskiy,RU
# processing request 109: city name --- Carnarvon,AU
# processing request 110: city name --- Sorland,NO
# processing request 111: city name --- Vaini,TO
# processing request 112: city name --- Mezen,RU
# processing request 113: city name --- Sotouboua,TG
# processing request 114: city name --- Lavrentiya,RU
# processing request 115: city name --- Mount gambier,AU
# City Not Found, skipping
# processing request 117: city name --- Iwaki,JP
# processing request 118: city name --- Tawau,MY
# processing request 119: city name --- Kushiro,JP
# processing request 120: city name --- Warrington,US
# processing request 121: city name --- Hasaki,JP
# processing request 122: city name --- Morehead,PG
# processing request 123: city name --- Coihaique,CL
# City Not Found, skipping
# City Not Found, skipping
# processing request 126: city name --- Thaton,MM
# processing request 127: city name --- Katsuura,JP
# processing request 128: city name --- Grand-santi,GF
# processing request 129: city name --- Tuktoyaktuk,CA
# City Not Found, skipping
# processing request 131: city name --- Lebu,CL
# processing request 132: city name --- Virginia beach,US
# processing request 133: city name --- Nuuk,GL
# processing request 134: city name --- Kaitangata,NZ
# processing request 135: city name --- Marawi,SD
# processing request 136: city name --- Punta alta,AR
# processing request 137: city name --- Hamilton,BM
# processing request 138: city name --- Maxixe,MZ
# processing request 139: city name --- Muros,ES
# processing request 140: city name --- Anadyr,RU
# processing request 141: city name --- Komsomolskiy,RU
# processing request 142: city name --- Buala,SB
# processing request 143: city name --- Iskateley,RU
# processing request 144: city name --- Manono,CD
# processing request 145: city name --- Bilibino,RU
# processing request 146: city name --- Sandy bay,HN
# City Not Found, skipping
# City Not Found, skipping
# processing request 149: city name --- Klaksvik,FO
# processing request 150: city name --- Ulladulla,AU
# City Not Found, skipping
# City Not Found, skipping
# processing request 153: city name --- Ajdabiya,LY
# processing request 154: city name --- Kungurtug,RU
# processing request 155: city name --- Hofn,IS
# processing request 156: city name --- Marsh harbour,BS
# processing request 157: city name --- Mahebourg,MU
# City Not Found, skipping
# processing request 159: city name --- Tiksi,RU
# processing request 160: city name --- Awjilah,LY
# City Not Found, skipping
# processing request 162: city name --- Louga,SN
# processing request 163: city name --- Mar del plata,AR
# processing request 164: city name --- San sebastian coatan,GT
# processing request 165: city name --- Benguela,AO
# processing request 166: city name --- Sagua de tanamo,CU
# processing request 167: city name --- Salalah,OM
# processing request 168: city name --- Thinadhoo,MV
# processing request 169: city name --- Manta,EC
# processing request 170: city name --- Port-gentil,GA
# processing request 171: city name --- Havelock,US
# processing request 172: city name --- Nobres,BR
# processing request 173: city name --- Batemans bay,AU
# processing request 174: city name --- Palmer,US
# City Not Found, skipping
# processing request 176: city name --- Samarai,PG
# City Not Found, skipping
# City Not Found, skipping
# processing request 179: city name --- Nagato,JP
# processing request 180: city name --- Dhidhdhoo,MV
# processing request 181: city name --- Karasburg,NA
# processing request 182: city name --- Saint-pierre,PM
# processing request 183: city name --- Raudeberg,NO
# processing request 184: city name --- Mizdah,LY
# processing request 185: city name --- Huntsville,US
# processing request 186: city name --- Lagoa,PT
# processing request 187: city name --- Tumaco,CO
# processing request 188: city name --- Erenhot,CN
# City Not Found, skipping
# processing request 190: city name --- Poum,NC
# processing request 191: city name --- Novyy urengoy,RU
# processing request 192: city name --- Cherskiy,RU
# processing request 193: city name --- Chabahar,IR
# processing request 194: city name --- Farafangana,MG
# processing request 195: city name --- Sao paulo de olivenca,BR
# City Not Found, skipping
# processing request 197: city name --- Cabatuan,PH
# processing request 198: city name --- Sur,OM
# processing request 199: city name --- Lorengau,PG
# processing request 200: city name --- Worland,US
# processing request 201: city name --- Longyearbyen,SJ
# processing request 202: city name --- Genhe,CN
# processing request 203: city name --- Providencia,MX
# processing request 204: city name --- Tiarei,PF
# processing request 205: city name --- Cayenne,GF
# processing request 206: city name --- Robertsport,LR
# City Not Found, skipping
# processing request 208: city name --- Ternate,ID
# processing request 209: city name --- Adrar,DZ
# processing request 210: city name --- West wendover,US
# processing request 211: city name --- Oistins,BB
# processing request 212: city name --- Luena,AO
# City Not Found, skipping
# City Not Found, skipping
# processing request 215: city name --- Thompson,CA
# processing request 216: city name --- Vardo,NO
# City Not Found, skipping
# processing request 218: city name --- Penzance,GB
# processing request 219: city name --- Chuy,UY
# City Not Found, skipping
# processing request 221: city name --- Mount isa,AU
# processing request 222: city name --- Tagusao,PH
# processing request 223: city name --- Churapcha,RU
# processing request 224: city name --- Fukue,JP
# processing request 225: city name --- Ojinaga,MX
# processing request 226: city name --- Vilhena,BR
# processing request 227: city name --- Arraial do cabo,BR
# processing request 228: city name --- Tabuk,SA
# City Not Found, skipping
# processing request 230: city name --- Ilam,IR
# processing request 231: city name --- Port elizabeth,ZA
# processing request 232: city name --- Tromso,NO
# processing request 233: city name --- Lufilufi,WS
# processing request 234: city name --- Ulagan,RU
# processing request 235: city name --- Hibbing,US
# processing request 236: city name --- Mount pleasant,US
# City Not Found, skipping
# processing request 238: city name --- Bethel,US
# processing request 239: city name --- Touros,BR
# processing request 240: city name --- Simao,CN
# processing request 241: city name --- Tambovka,RU
# processing request 242: city name --- Voyinka,UA
# processing request 243: city name --- Cidreira,BR
# processing request 244: city name --- Narsaq,GL
# processing request 245: city name --- Ocos,GT
# processing request 246: city name --- Kaputa,ZM
# processing request 247: city name --- Dicabisagan,PH
# processing request 248: city name --- Antalaha,MG
# processing request 249: city name --- Charters towers,AU
# City Not Found, skipping
# processing request 251: city name --- Hay river,CA
# processing request 252: city name --- Kodinsk,RU
# processing request 253: city name --- Palwal,IN
# processing request 254: city name --- Namatanai,PG
# processing request 255: city name --- Guerrero negro,MX
# processing request 256: city name --- Meulaboh,ID
# processing request 257: city name --- Kloulklubed,PW
# City Not Found, skipping
# processing request 259: city name --- Norsup,VU
# processing request 260: city name --- Santiago,PE
# processing request 261: city name --- Tommot,RU
# City Not Found, skipping
# processing request 263: city name --- Buraydah,SA
# processing request 264: city name --- General roca,AR
# processing request 265: city name --- Praia da vitoria,PT
# processing request 266: city name --- Axim,GH
# processing request 267: city name --- Torbay,CA
# processing request 268: city name --- Upernavik,GL
# processing request 269: city name --- Manado,ID
# processing request 270: city name --- Mahajanga,MG
# City Not Found, skipping
# City Not Found, skipping
# City Not Found, skipping
# processing request 274: city name --- Bud,NO
# processing request 275: city name --- Clyde river,CA
# processing request 276: city name --- San pedro,AR
# processing request 277: city name --- Sechura,PE
# processing request 278: city name --- Sarkand,KZ
# City Not Found, skipping
# processing request 280: city name --- Saint-nazaire,FR
# processing request 281: city name --- Acapulco,MX
# processing request 282: city name --- Pasighat,IN
# processing request 283: city name --- Alekseyevskoye,RU
# processing request 284: city name --- Talnakh,RU
# processing request 285: city name --- Northam,AU
# City Not Found, skipping
# processing request 287: city name --- At-bashi,KG
# City Not Found, skipping
# processing request 289: city name --- Bireun,ID
# processing request 290: city name --- Broome,AU
# processing request 291: city name --- Reconquista,AR
# processing request 292: city name --- Barrow,US
# processing request 293: city name --- Nanortalik,GL
# processing request 294: city name --- Kjopsvik,NO
# City Not Found, skipping
# processing request 296: city name --- Port blair,IN
# City Not Found, skipping
# processing request 298: city name --- Berdyaush,RU
# processing request 299: city name --- Xining,CN
# City Not Found, skipping
# processing request 301: city name --- Sao joao da barra,BR
# City Not Found, skipping
# processing request 303: city name --- Kutum,SD
# processing request 304: city name --- Roebourne,AU
# City Not Found, skipping
# processing request 306: city name --- Tessalit,ML
# processing request 307: city name --- Chesterville,CA
# processing request 308: city name --- Presidencia roque saenz pena,AR
# processing request 309: city name --- Otavi,NA
# processing request 310: city name --- Goma,CD
# processing request 311: city name --- Saldanha,ZA
# processing request 312: city name --- Lompoc,US
# processing request 313: city name --- Whitehorse,CA
# processing request 314: city name --- Masingbi,SL
# processing request 315: city name --- Chuchkovo,RU
# City Not Found, skipping
# processing request 317: city name --- Vanimo,PG
# processing request 318: city name --- Victoria,SC
# processing request 319: city name --- Provideniya,RU
# processing request 320: city name --- San carlos de bariloche,AR
# processing request 321: city name --- Eureka,US
# processing request 322: city name --- Qasigiannguit,GL
# processing request 323: city name --- Jasper,CA
# processing request 324: city name --- Luderitz,NA
# City Not Found, skipping
# processing request 326: city name --- Harper,LR
# processing request 327: city name --- Moranbah,AU
# processing request 328: city name --- Nelson bay,AU
# City Not Found, skipping
# processing request 330: city name --- Hami,CN
# processing request 331: city name --- Puerto madero,MX
# processing request 332: city name --- Vila franca do campo,PT
# City Not Found, skipping
# processing request 334: city name --- Saint george,BM
# processing request 335: city name --- Puno,PE
# processing request 336: city name --- Makakilo city,US
# processing request 337: city name --- Pimentel,PE
# processing request 338: city name --- Jizan,SA
# processing request 339: city name --- Tuatapere,NZ
# City Not Found, skipping
# processing request 341: city name --- Rio tercero,AR
# processing request 342: city name --- Kargat,RU
# processing request 343: city name --- Dhrangadhra,IN
# processing request 344: city name --- Fuerte olimpo,PY
# processing request 345: city name --- Bonga,ET
# processing request 346: city name --- Kropotkin,RU
# processing request 347: city name --- Auki,SB
# processing request 348: city name --- Hambantota,LK
# City Not Found, skipping
# processing request 350: city name --- Divnomorskoye,RU
# City Not Found, skipping
# processing request 352: city name --- Bria,CF
# processing request 353: city name --- Ellensburg,US
# processing request 354: city name --- Maceio,BR
# processing request 355: city name --- Brae,GB
# processing request 356: city name --- Orbetello,IT
# processing request 357: city name --- Hirara,JP
# processing request 358: city name --- Kuching,MY
# processing request 359: city name --- Omboue,GA
# processing request 360: city name --- Kemi,FI
# City Not Found, skipping
# processing request 362: city name --- Dukat,RU
# processing request 363: city name --- Mangai,CD
# processing request 364: city name --- Lotoshino,RU
# processing request 365: city name --- Kargasok,RU
# processing request 366: city name --- Jacksonville,US
# processing request 367: city name --- Phalodi,IN
# processing request 368: city name --- Okato,NZ
# processing request 369: city name --- Mareeba,AU
# processing request 370: city name --- Leningradskiy,RU
# processing request 371: city name --- Jejuri,IN
# processing request 372: city name --- Gizo,SB
# processing request 373: city name --- Leh,IN
# processing request 374: city name --- Filadelfia,PY
# processing request 375: city name --- Hovd,MN
# processing request 376: city name --- Laurel,US
# City Not Found, skipping
# processing request 378: city name --- Rawson,AR
# processing request 379: city name --- Dalvik,IS
# processing request 380: city name --- Tecoanapa,MX
# processing request 381: city name --- Iqaluit,CA
# processing request 382: city name --- Iquitos,PE
# processing request 383: city name --- Isilkul,RU
# processing request 384: city name --- Karla,EE
# processing request 385: city name --- Kurilsk,RU
# City Not Found, skipping
# processing request 387: city name --- Blyth,GB
# City Not Found, skipping
# City Not Found, skipping
# processing request 390: city name --- Shelton,US
# processing request 391: city name --- Avarua,CK
# processing request 392: city name --- Mayumba,GA
# processing request 393: city name --- Palu,ID
# processing request 394: city name --- Pacific grove,US
# processing request 395: city name --- Salinas,BR
# City Not Found, skipping
# processing request 397: city name --- San bonifacio,IT
# processing request 398: city name --- Birkeland,NO
# processing request 399: city name --- Sangar,RU
# processing request 400: city name --- Hof,NO
# processing request 401: city name --- Atar,MR
# processing request 402: city name --- High rock,BS
# processing request 403: city name --- Kernersville,US
# processing request 404: city name --- Osmena,PH
# processing request 405: city name --- Ordzhonikidze,UA
# City Not Found, skipping
# processing request 407: city name --- Bucerias,MX
# processing request 408: city name --- Takefu,JP
# processing request 409: city name --- Shubarshi,KZ
# processing request 410: city name --- Deputatskiy,RU
# processing request 411: city name --- Sarny,UA
# processing request 412: city name --- Maloy,NO
# City Not Found, skipping
# City Not Found, skipping
# processing request 415: city name --- Whyalla,AU
# processing request 416: city name --- Ivankiv,UA
# processing request 417: city name --- Bonavista,CA
# processing request 418: city name --- Saquarema,BR
# processing request 419: city name --- Silver city,US
# City Not Found, skipping
# processing request 421: city name --- Inhambane,MZ
# City Not Found, skipping
# processing request 423: city name --- Kamyaran,IR
# processing request 424: city name --- Los llanos de aridane,ES
# processing request 425: city name --- Sawtell,AU
# processing request 426: city name --- Derzhavinsk,KZ
# processing request 427: city name --- Fairbanks,US
# processing request 428: city name --- Te anau,NZ
# processing request 429: city name --- Lazaro cardenas,MX
# processing request 430: city name --- Nhulunbuy,AU
# processing request 431: city name --- Kuyanovo,RU
# processing request 432: city name --- Cabo san lucas,MX
# processing request 433: city name --- Erzin,RU
# processing request 434: city name --- Shingu,JP
# processing request 435: city name --- Broken hill,AU
# processing request 436: city name --- Byron bay,AU
# processing request 437: city name --- Hervey bay,AU
# processing request 438: city name --- Pogana,RO
# processing request 439: city name --- Zhangjiakou,CN
# processing request 440: city name --- Puri,IN
# processing request 441: city name --- Antofagasta,CL
# processing request 442: city name --- Kuopio,FI
# processing request 443: city name --- Arkhangelsk,RU
# processing request 444: city name --- Caconda,AO
# processing request 445: city name --- Bambanglipuro,ID
# processing request 446: city name --- Padang,ID
# processing request 447: city name --- Wloszczowa,PL
# processing request 448: city name --- Suoyarvi,RU
# processing request 449: city name --- Paka,MY
# processing request 450: city name --- Ilulissat,GL
# processing request 451: city name --- Koumac,NC
# processing request 452: city name --- Hearst,CA
# processing request 453: city name --- Noumea,NC
# processing request 454: city name --- Makinsk,KZ
# processing request 455: city name --- Hammerfest,NO
# processing request 456: city name --- Inirida,CO
# City Not Found, skipping
# processing request 458: city name --- Saryozek,KZ
# processing request 459: city name --- Hauzenberg,DE
# processing request 460: city name --- Oksfjord,NO
# processing request 461: city name --- Sidi ali,DZ
# processing request 462: city name --- Coquimbo,CL
# processing request 463: city name --- Lahij,YE
# processing request 464: city name --- Zaragoza,MX
# City Not Found, skipping
# processing request 466: city name --- Felanitx,ES
# processing request 467: city name --- Kieta,PG
# processing request 468: city name --- Kavaratti,IN
# processing request 469: city name --- Keffi,NG
# processing request 470: city name --- Bukama,CD
# processing request 471: city name --- Novouzensk,RU
# processing request 472: city name --- Necocli,CO
# processing request 473: city name --- Youghal,IE
# processing request 474: city name --- Lalsk,RU
# processing request 475: city name --- Eidsvag,NO
# processing request 476: city name --- Champerico,GT
# processing request 477: city name --- Almenara,BR
# processing request 478: city name --- Cabra,PH
# processing request 479: city name --- Dingle,IE
# processing request 480: city name --- Mandalgovi,MN
# processing request 481: city name --- Araouane,ML
# processing request 482: city name --- Mumford,GH
# processing request 483: city name --- Lubumbashi,CD
# processing request 484: city name --- Szekkutas,HU
# processing request 485: city name --- Mae hong son,TH
# City Not Found, skipping
# City Not Found, skipping
# processing request 488: city name --- Westport,NZ
# processing request 489: city name --- Umm lajj,SA
# processing request 490: city name --- Mpika,ZM
# processing request 491: city name --- Anuradhapura,LK
# processing request 492: city name --- Barbosa ferraz,BR
# processing request 493: city name --- Ivanovka,RU
# processing request 494: city name --- Batagay-alyta,RU
# processing request 495: city name --- Namibe,AO
# processing request 496: city name --- Turukhansk,RU
# processing request 497: city name --- Bakchar,RU
# City Not Found, skipping
# processing request 499: city name --- Madang,PG
# processing request 500: city name --- Laplace,US
# processing request 501: city name --- Les cayes,HT
# processing request 502: city name --- Zalantun,CN
# processing request 503: city name --- Challans,FR
# processing request 504: city name --- Karatuzskoye,RU
# processing request 505: city name --- Newcastleton,GB
# processing request 506: city name --- Mirabad,AF
# processing request 507: city name --- Shache,CN
# processing request 508: city name --- Mogadishu,SO
# processing request 509: city name --- Denpasar,ID
# City Not Found, skipping
# processing request 511: city name --- Nortelandia,BR
# processing request 512: city name --- Trat,TH
# City Not Found, skipping
# processing request 514: city name --- Nador,MA
# processing request 515: city name --- Pemberton,CA
# processing request 516: city name --- Ancud,CL
# processing request 517: city name --- Peace river,CA
# processing request 518: city name --- Palana,RU
# City Not Found, skipping
# processing request 520: city name --- Green river,US
# processing request 521: city name --- Ust-kuyga,RU
# processing request 522: city name --- Ahuimanu,US
# processing request 523: city name --- Progreso,MX
# processing request 524: city name --- Karratha,AU
# City Not Found, skipping
# processing request 526: city name --- Mana,GF
# processing request 527: city name --- Longfeng,CN
# processing request 528: city name --- Vostok,RU
# processing request 529: city name --- Santo antonio de posse,BR
# processing request 530: city name --- Shenavan,AM
# processing request 531: city name --- Port augusta,AU
# processing request 532: city name --- Kimbe,PG
# processing request 533: city name --- Pomabamba,PE
# processing request 534: city name --- Tikrit,IQ
# processing request 535: city name --- Synya,RU
# processing request 536: city name --- Pangnirtung,CA
# processing request 537: city name --- Altea,ES
# City Not Found, skipping
# processing request 539: city name --- Saryg-sep,RU
# City Not Found, skipping
# processing request 541: city name --- Moyale,ET
# processing request 542: city name --- Antequera,PY
# processing request 543: city name --- Kharan,PK
# processing request 544: city name --- Ingham,AU
# processing request 545: city name --- Jiuquan,CN
# processing request 546: city name --- Peniche,PT
# processing request 547: city name --- Sobolevo,RU
# processing request 548: city name --- Dodoma,TZ
# processing request 549: city name --- Dubrovnik,HR
# processing request 550: city name --- Do gonbadan,IR
# processing request 551: city name --- Fort frances,CA
# City Not Found, skipping
# processing request 553: city name --- Jiayuguan,CN
# processing request 554: city name --- Ambon,ID
# processing request 555: city name --- Bardiyah,LY
# processing request 556: city name --- Almaznyy,RU
# processing request 557: city name --- Ludvika,SE
# processing request 558: city name --- Nurota,UZ
# City Not Found, skipping
# processing request 560: city name --- Portland,AU
# processing request 561: city name --- Latung,PH
# City Not Found, skipping
# processing request 563: city name --- Pontianak,ID
# processing request 564: city name --- Mopipi,BW
# processing request 565: city name --- Tilichiki,RU
# processing request 566: city name --- Kawalu,ID
# processing request 567: city name --- Talaya,RU
# processing request 568: city name --- Hanna,CA
# processing request 569: city name --- Roald,NO
# processing request 570: city name --- Sisimiut,GL
# processing request 571: city name --- Cockburn town,TC
# processing request 572: city name --- Livingstone,ZM
# processing request 573: city name --- Jiamusi,CN
# processing request 574: city name --- Kruisfontein,ZA
# processing request 575: city name --- Mutoko,ZW
# processing request 576: city name --- Cabimas,VE
# processing request 577: city name --- Ginir,ET
# processing request 578: city name --- Lusambo,CD
# processing request 579: city name --- Sitka,US
# processing request 580: city name --- Sabancuy,MX
# processing request 581: city name --- Zyryanka,RU
# processing request 582: city name --- Santa cruz,CR
# processing request 583: city name --- Flinders,AU
# processing request 584: city name --- Ottawa,US
# processing request 585: city name --- Vostochnyy,RU
# processing request 586: city name --- Besenyotelek,HU
# processing request 587: city name --- Neuquen,AR
# processing request 588: city name --- Port lincoln,AU
# processing request 589: city name --- George,ZA
# processing request 590: city name --- Teguldet,RU
# processing request 591: city name --- Kanniyakumari,IN
# processing request 592: city name --- Ocampo,MX
# processing request 593: city name --- Chernyshevskiy,RU
# processing request 594: city name --- Capitan bado,PY

# %%
df.head()
# Out:
#           Country    Lat     Lng        Date     Temp Cloudiness Humidity  \
# City
# toliary        mg
# rocha          uy -34.48  -54.34  1551644319  298.497          0       41
# hermanus       za -34.42   19.24  1551644255   291.06          0       92
# fortuna        us   40.6 -124.16  1551644170   286.05         90      100
# busselton      au -33.64  115.35  1551643995   290.09          0       43
#
#           Wind speed
# City
# toliary
# rocha           3.32
# hermanus        0.45
# fortuna          2.6
# busselton       8.92

# %%
df['Lat'].replace('', np.nan, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#           Country    Lat     Lng        Date     Temp Cloudiness Humidity  \
# City
# rocha          uy -34.48  -54.34  1551644319  298.497          0       41
# hermanus       za -34.42   19.24  1551644255   291.06          0       92
# fortuna        us  40.60 -124.16  1551644170   286.05         90      100
# busselton      au -33.64  115.35  1551643995   290.09          0       43
# killybegs      ie  54.63   -8.45  1551644224   278.64         20       61
#
#           Wind speed
# City
# rocha           3.32
# hermanus        0.45
# fortuna          2.6
# busselton       8.92
# killybegs        7.2
